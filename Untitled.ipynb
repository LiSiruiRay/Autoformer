# %%
import numpy as np
import matplotlib.pyplot as pyplot

def get_sin(num_points: int = 1000):
    # Parameters
    #frequency = 1.0  # Frequency of the sine wave
    duration = num_points/100   # Duration of the sine wave in seconds
    sample_rate = 100  # Sampling rate (samples per second)

    # Generate a time vector
    t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)
    frequency_start = 1  # Initial frequency in Hz
    frequency_end =  2 # Final frequency in Hz
    frequency = np.linspace(frequency_start, frequency_end, len(t))
    # Generate a sine wave with increasing amplitude
    amplitude1 = np.linspace(5, 1, len(t))  # Decreasing amplitude
    sine_wave1 = amplitude1 * np.sin(2 * np.pi * frequency * t)
    line1      = 2*t+1
    noise = np.random.normal(0, 1, num_points)

    signal1    = sine_wave1 + line1+0.5*noise
    
    # Add peaks
    for i in range(100,1000,100):
        
        signal1[i:i+30] += 3
    
    pyplot.plot(t, signal1, label='Sine Wave with Varying Amplitude and Trend')
    pyplot.xlabel('Time (s)')
    pyplot.ylabel('Amplitude')
    pyplot.grid(True)
    pyplot.legend()
    pyplot.title('Sine Wave with Varying Amplitude and Trend')
    pyplot.show()
    return signal1
    
def get_sin_2(num_points: int = 1000):
    # Parameters
    #frequency = 1.0  # Frequency of the sine wave
    duration = num_points / 100.0   # Duration of the sine wave in seconds
    sample_rate = 1000  # Sampling rate (samples per second)

    # Generate a time vector
    t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)
    frequency_start = 1  # Initial frequency in Hz
    frequency_end =  5 # Final frequency in Hz
    frequency = np.linspace(frequency_start, frequency_end, len(t))
    # Generate a sine wave with increasing amplitude
    amplitude1 = np.linspace(5, 1, len(t))  # Increasing amplitude
    sine_wave1 = amplitude1 * np.sin(2 * np.pi * frequency * t)
    line1      = 5*np.exp(-2*t**2)+1
    noise = np.random.normal(0, 1, num_points * 10)

    signal1    = sine_wave1 + line1+0.5*noise
    
    # Add peaks
    for i in range(100,10000,500):
        
        signal1[i:i+30] += 3
    
    pyplot.plot(t, signal1, label='Sine Wave with Varying Amplitude and Trend')
    pyplot.xlabel('Time (s)')
    pyplot.ylabel('Amplitude')
    pyplot.grid(True)
    pyplot.legend()
    pyplot.title('Sine Wave with Varying Amplitude and Trend')
    pyplot.show()
    return signal1

# %%
num_points = 17420
result = get_sin(num_points = num_points)

# %%
result = get_sin_2()

# %%
type(result)
# Out:
# numpy.ndarray

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset/ETT-small/ETTm2.csv')

# %%
df
# Out:
#                       date       HUFL    HULL       MUFL    MULL    LUFL  \
# 0      2016-07-01 00:00:00  41.130001  12.481  36.535999   9.355   4.424
# 1      2016-07-01 00:15:00  39.622002  11.309  35.543999   8.551   3.209
# 2      2016-07-01 00:30:00  38.868000  10.555  34.365002   7.586   4.435
# 3      2016-07-01 00:45:00  35.518002   9.214  32.569000   8.712   4.435
# 4      2016-07-01 01:00:00  37.528000  10.136  33.936001   7.532   4.435
# ...                    ...        ...     ...        ...     ...     ...
# 69675  2018-06-26 18:45:00  42.722000  12.230  54.014000  12.652 -11.525
# 69676  2018-06-26 19:00:00  38.868000  10.052  49.859001  10.669 -11.525
# 69677  2018-06-26 19:15:00  39.622002  11.057  50.448002  11.795 -10.299
# 69678  2018-06-26 19:30:00  40.459999  11.392  51.841999  11.929 -11.536
# 69679  2018-06-26 19:45:00  43.223999  12.146  54.737000  12.679 -11.536
#
#         LULL         OT
# 0      1.311  38.661999
# 1      1.258  38.223000
# ...

# %%
len(result)
# Out:
# 10000

# %%
cut_df = df[:10000]

# %%
cut_df
# Out:
#                      date       HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# 0     2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 1     2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2     2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 3     2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 4     2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
# ...                   ...        ...     ...        ...    ...    ...    ...
# 9995  2016-10-13 02:45:00  35.518002   9.968  31.389999  7.211  3.859  1.311
# 9996  2016-10-13 03:00:00  38.366001  11.225  35.356998  8.524  3.859  1.311
# 9997  2016-10-13 03:15:00  39.455002  12.481  35.652000  9.168  3.966  1.311
# 9998  2016-10-13 03:30:00  36.689999  10.806  32.596001  7.774  3.966  1.311
# 9999  2016-10-13 03:45:00  35.349998  10.052  32.085999  7.532  3.966  1.311
#
#              OT
# 0     38.661999
# ...

# %%
cut_df['OT'] = result
# Out:
# /var/folders/3c/4336tt352pn6hnc003pk93080000gn/T/ipykernel_18914/178840741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['OT'] = result

# %%
cut_df
# Out:
#                      date       HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# 0     2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 1     2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2     2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 3     2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 4     2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
# ...                   ...        ...     ...        ...    ...    ...    ...
# 9995  2016-10-13 02:45:00  35.518002   9.968  31.389999  7.211  3.859  1.311
# 9996  2016-10-13 03:00:00  38.366001  11.225  35.356998  8.524  3.859  1.311
# 9997  2016-10-13 03:15:00  39.455002  12.481  35.652000  9.168  3.966  1.311
# 9998  2016-10-13 03:30:00  36.689999  10.806  32.596001  7.774  3.966  1.311
# 9999  2016-10-13 03:45:00  35.349998  10.052  32.085999  7.532  3.966  1.311
#
#             OT
# 0     5.581108
# ...

# %%
cut_df = cut_df[['date', 'OT']]

# %%
cut_df
# Out:
#                      date        OT
# 0     2016-07-01 00:00:00  5.581108
# 1     2016-07-01 00:15:00  5.691188
# 2     2016-07-01 00:30:00  6.625657
# 3     2016-07-01 00:45:00  6.472990
# 4     2016-07-01 01:00:00  6.181487
# ...                   ...       ...
# 9995  2016-10-13 02:45:00  0.291540
# 9996  2016-10-13 03:00:00  0.511441
# 9997  2016-10-13 03:15:00  0.707830
# 9998  2016-10-13 03:30:00  1.045112
# 9999  2016-10-13 03:45:00  0.789128
#
# [10000 rows x 2 columns]

# %%
cut_df.to_csv('dataset/self_made/sin_on_line_10k.csv', index=False)
